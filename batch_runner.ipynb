# %%
import pandas as pd
from bs4 import BeautifulSoup
import unicodedata
import requests
import re
import lib.database as db
from lib.reconst import MONTH_REGEX
import datetime
from datetime import date
import lib.ical_scraper as ical_s
import lib.js_scraper as js_s
import lib.airtable_scraper as air_s
import subprocess
import sys
import glob

# %%
df = pd.read_csv(
    'https://docs.google.com/spreadsheets/d/e/2PACX-1vR0wN4cYWlVyurisDpqUj9wVrZf52NbSIYbDg2hrWXiyH0LJf8nt3YpXSNND9W96c3tOxE3pws6ERkf/pub?gid=324812982&single=true&output=csv'
)

# %%
df
# Out:
#     Board    Borough             Type  \
# 0     102  Manhattan             ical
# 1     103  Manhattan             HTML
# 2     104  Manhattan             ical
# 3     105  Manhattan  Google calendar
# 4     106  Manhattan             HTML
# 5     107  Manhattan             HTML
# 6     108  Manhattan             ical
# 7     110  Manhattan             ical
# 8     112  Manhattan             ical
# 9     206      Bronx             HTML
# 10    209      Bronx             HTML
# 11    302   Brooklyn  Google calendar
# 12    303   Brooklyn  Google calendar
# 13    305   Brooklyn  Google calendar
# 14    306   Brooklyn         LinkTree
# 15    307   Brooklyn             HTML
# 16    308   Brooklyn  Google calendar
# 17    310   Brooklyn             ical
# 18    311   Brooklyn             ical
# 19    317   Brooklyn             ical
# 20    402     Queens           custom
# 21    406     Queens  Google calendar
# 22    413     Queens  Google calendar
# ...

# %%
python_exe = sys.executable

# %%
# Set the directory and the pattern for the .py files
directory = "CB_scrapers"
pattern = "1*.py"

# Use glob.glob() to get a list of .py files that match the pattern
file_list = glob.glob(f"{directory}/{pattern}")

# %%
for file in file_list:
    print(f"Running: {file}")
    
    # Use subprocess.run() to execute the Python file
    result = subprocess.run(["python", file], capture_output=True, text=True)

    # Print the output of the executed script
    print("Output:", result.stdout)
    print("Errors:", result.stderr)
# Out:
# Running: CB_scrapers\101.py
# Output: PDF downloaded successfully as April%202023 calendar.pdf
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# b
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# b
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Waterfront, Parks &
# Cultural Committee
#
# CB 1’s Monthly Board
# Meeting
#
# Sun. Monday Tuesday Wednesday Thursday Fri. Sat.
# 1
# 2 3 4 6:00 PM | 5 6 7 8
# Transportation & Street
# Activity Permits
# Committee
# 9 10 6:00 PM | 11 6:00 PM | 12 6:00 PM | 13 6:00 PM | 14 15
# Land Use, Zoning & Battery Park City Licensing & Permits Landmarks & Preservation
# Economic Committee Committee Committee
# Development
# Committee
# 16 17 18 6:00 PM | 19 6:00 PM | 20 6:00 PM | 21 22
# Environmental Quality of Life & Service Executive Committee
# ...

# %%
def runScript(file):
    print(file)
    try:
        result = subprocess.run([python_exe,file], capture_output = True, encoding = 'UTF-8')
#         else:
#             functionLookUp[row['Type']](row['Url'], int(row['Board']))
        return True
    except Exception as e:
        if hasattr(e, 'message'):
            return(e.message)
        else:
            return e

# %%
for file in file_list:
    output = runScript(file)
    print(output)
# Out:
# CB_scrapers\101.py
# True
# CB_scrapers\102.py
# True
# CB_scrapers\103.py
# True
# CB_scrapers\104.py
# True
# CB_scrapers\105.py
# True
# CB_scrapers\106.py
# True
# CB_scrapers\107.py
# True
# CB_scrapers\108.py
# True
# CB_scrapers\109.py
# True
# CB_scrapers\110.py
# True
# CB_scrapers\111.py
# True
# CB_scrapers\112.py
# True

# %%
def runScript(row):
    print(row['Board'])
    try:
        if row['Type'] not in functionLookUp:
            scriptName = row['Custom Script']
            result = subprocess.run([python_exe,scriptName], capture_output = True, encoding = 'UTF-8')
            return(result)
#         else:
#             functionLookUp[row['Type']](row['Url'], int(row['Board']))
        return True
    except Exception as e:
        if hasattr(e, 'message'):
            return(e.message)
        else:
            return e

def ical_function(url, district):
    today = date.today()
    url = url + str(today.strftime("%Y")) + '-' + str(today.strftime("%m")) + '/' + '?ical=1'
    events_dict = icalscr.ical_scraper(url)
    database = db.Database(district)
    database.addDictionary(events_dict)

def gcal_function(url, district):
    events_dict = icalscr.ical_scraper(url)
    database = db.Database(district)
    database.addDictionary(events_dict)
    
def js_function(url, district):
    events_dict = js_scr.js_scraper(url)
    database = db.Database(district)
    database.addDictionary(events_dict)
    

functionLookUp = {'ical': ical_function, 'Google calendar': gcal_function, 'js': js_function}

# %%
df1 = df.apply(runScript,axis = 1)
# Out:
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 110
# 112
# 206
# 209
# 302
# 303
# 305
# 306
# 307
# 308
# 310
# 311
# 317
# 402
# 406
# 413
# 403
# 301
# 312
# 405

# %%
df1[1]
# Out:
# CompletedProcess(args=['C:\\Users\\ebroh\\miniconda3\\envs\\geo\\python.exe', '103.py'], returncode=0, stdout='', stderr='')
